# %% [markdown]
# ### Assignment no - 20 Building & Deplyoing a Recommendation system
# ## PART 1- Data Processing
# # Task 1:- Load and understand Dataset

# %%
import pandas as pd
import scipy

# %%
d1=pd.read_csv('books.csv')

d2=pd.read_csv('book_tags.csv')

d3=pd.read_csv('tags.csv')

# %%
d1.shape
# Out:
# (10000, 23)

# %%
d2.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
d2.shape
# Out:
# (999912, 3)

# %%
d3.shape
# Out:
# (34252, 2)

# %%
d1.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
d2.head(3)
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173

# %%
d3.head(3)
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-

# %%
# Merge d2 with d3 to get readable tag names.

merged_tags = d2.merge(d3,on='tag_id',how='left')

merged_tags.head()
# Out:
#    goodreads_book_id  tag_id   count           tag_name
# 0                  1   30574  167697            to-read
# 1                  1   11305   37174            fantasy
# 2                  1   11557   34173          favorites
# 3                  1    8717   12986  currently-reading
# 4                  1   33114   12716        young-adult

# %%
# Collect Tags for Each Book

d2_grouped = (merged_tags.groupby('goodreads_book_id')['tag_name'].apply(lambda x: ' '.join(x.astype(str))).reset_index())

# %%
d2_grouped.head()
# Out:
#    goodreads_book_id                                           tag_name
# 0                  1  to-read fantasy favorites currently-reading yo...
# 1                  2  to-read currently-reading fantasy favorites ch...
# 2                  3  to-read favorites fantasy currently-reading yo...
# 3                  5  favorites fantasy currently-reading young-adul...
# 4                  6  fantasy young-adult fiction harry-potter owned...

# %%
d1.columns.tolist()
# Out:
# ['book_id',
#  'goodreads_book_id',
#  'best_book_id',
#  'work_id',
#  'books_count',
#  'isbn',
#  'isbn13',
#  'authors',
#  'original_publication_year',
#  'original_title',
#  'title',
#  'language_code',
#  'average_rating',
#  'ratings_count',
#  'work_ratings_count',
#  'work_text_reviews_count',
#  'ratings_1',
#  'ratings_2',
#  'ratings_3',
#  'ratings_4',
#  'ratings_5',
#  'image_url',
#  'small_image_url']

# %%
# Merge tags with Books

books = d1.merge(d2_grouped,on = 'goodreads_book_id',how = 'left')

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   book_id                    10000 non-null  int64
#  1   goodreads_book_id          10000 non-null  int64
#  2   best_book_id               10000 non-null  int64
#  3   work_id                    10000 non-null  int64
#  4   books_count                10000 non-null  int64
#  5   isbn                       9300 non-null   object
#  6   isbn13                     9415 non-null   float64
#  7   authors                    10000 non-null  object
#  8   original_publication_year  9979 non-null   float64
#  9   original_title             9415 non-null   object
#  10  title                      10000 non-null  object
#  11  language_code              8916 non-null   object
#  12  average_rating             10000 non-null  float64
# ...

# %%
# Handling missing values

cols = ['title','authors','original_title','tag_name']
books = books[cols]

# %%
books[cols] = books[cols].fillna('')

# %%
books[cols].isnull().sum()
# Out:
# title             0
# authors           0
# original_title    0
# tag_name          0
# dtype: int64

# %%
books[cols].duplicated().sum()
# Out:
# np.int64(0)

# %%
books.head()
# Out:
#                                                title  \
# 0            The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2                            Twilight (Twilight, #1)
# 3                              To Kill a Mockingbird
# 4                                   The Great Gatsby
#
#                        authors                            original_title  \
# 0              Suzanne Collins                          The Hunger Games
# 1  J.K. Rowling, Mary GrandPré  Harry Potter and the Philosopher's Stone
# 2              Stephenie Meyer                                  Twilight
# 3                   Harper Lee                     To Kill a Mockingbird
# 4          F. Scott Fitzgerald                          The Great Gatsby
#
#                                             tag_name
# 0  favorites currently-reading young-adult fictio...
# 1  to-read favorites fantasy currently-reading yo...
# ...

# %%
books['text']=(books['title'].fillna('')+' '+books['authors'].fillna('')+' '+books['original_title'].fillna('')+' '+books['tag_name'].fillna('')).str.lower()

# %% [markdown]
# ## Task 2:- Text preprocessing for Recommendation

# %%
import nltk
import re
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Deepak
# [nltk_data]     Shukla\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# cleaning function
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9]',' ',text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return ' '.join(words)

# %%
# Apply
books['clean_text'] = books['text'].apply(clean_text)

# %% [markdown]
# ## PART 2- Text Vectorization
# # Task 3:- Vectorization using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=5000,stop_words='english',ngram_range=(1,2))

# %%
tfidf_matrix = tfidf.fit_transform(books['clean_text'])
print(tfidf_matrix.shape)
# Out:
# (10000, 5000)

# %% [markdown]
# # Task 4:- Similarity Coputation

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(tfidf_matrix)
print(similarity.shape)
# Out:
# (10000, 10000)

# %% [markdown]
# # Why cosine similarity?
# - Works well on Sparse TF-IDF vectors.
# - Measures similarity by comparing vector directions rather than document length.
# - Produces similarity scores between 0 and 1.
# - Widely used in content-based recommendation system.

# %% [markdown]
# ## PART 3- Recommendation Logic
# # Task 5:- Build Recommendation Function

# %%
def recommend(book_name, top_n=10):
    
    book_name = book_name.lower().strip()

    matches = books[books['title'].str.lower().str.contains(book_name, na=False)]
    if matches.empty:
        return 'Book not Found'

    idx = matches.index[0]

    sim_scores = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()

    top_indices = sim_scores.argsort()[-top_n-1:-1][::-1]
    recommendations = books.iloc[top_indices][['title','authors',]]
    return recommendations

# %%
recommend("the hobbit")
# Out:
#                                                   title  \
# 188   The Lord of the Rings (The Lord of the Rings, ...
# 154          The Two Towers (The Lord of the Rings, #2)
# 610            The Silmarillion (Middle-Earth Universe)
# 2308                              The Children of Húrin
# 18    The Fellowship of the Ring (The Lord of the Ri...
# 160   The Return of the King (The Lord of the Rings,...
# 963   J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 4975       Unfinished Tales of Númenor and Middle-Earth
# 8271                 The Complete Guide to Middle-Earth
# 1128   The History of the Hobbit, Part One: Mr. Baggins
#
#                                                authors
# 188                                     J.R.R. Tolkien
# 154                                     J.R.R. Tolkien
# 610   J.R.R. Tolkien, Christopher Tolkien, Ted Nasmith
# 2308     J.R.R. Tolkien, Christopher Tolkien, Alan Lee
# 18                                      J.R.R. Tolkien
# ...

# %% [markdown]
# ## PART 4 - Simple App Interface
# # Task 6:- Build UI using Streamlit

# %%
books_data = books[['title','authors','clean_text']]

# %%
import pickle
with open('books.pickle','wb') as B:
    pickle.dump(books_data,B)

# %%
with open('tfidf_matrix.pickle','wb') as B:
    pickle.dump(tfidf_matrix,B)
